# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("/content/drive/MyDrive/GUVI/GUVI Capstone 2/newcycdata.xlsx")
df.head()
# Out:
#    INDEX           ride_id  rideable_type member_casual  \
# 0      0  2B22BD5F95FB2629  electric_bike        casual
# 1      1  A7FB70B4AFC6CAF2  electric_bike        casual
# 2      2  86057FA01BAC778E  electric_bike        casual
# 3      3  57F6DC9A153DB98C  electric_bike        casual
# 4      4  B9C4712F78C1AE68  electric_bike        casual
#
#                start_station_name          started_at            ended_at  \
# 0          Michigan Ave & Lake St 2020-09-17 14:27:00 2020-09-17 14:44:00
# 1      W Oakdale Ave & N Broadway 2020-09-17 15:07:00 2020-09-17 15:07:00
# 2      W Oakdale Ave & N Broadway 2020-09-17 15:09:00 2020-09-17 15:09:00
# 3  Ashland Ave & Belle Plaine Ave 2020-09-17 18:10:00 2020-09-17 18:35:00
# 4        Fairbanks Ct & Grand Ave 2020-09-17 15:16:00 2020-09-17 15:52:00
#
#    start_station_id  end_station_id            end_station_name start_date  \
# 0              52.0           112.0      Green St & Randolph St 2020-09-17
# ...

# %%
df.shape
# Out:
# (500684, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500684 entries, 0 to 500683
# Data columns (total 14 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   INDEX               500684 non-null  int64
#  1   ride_id             500684 non-null  object
#  2   rideable_type       500684 non-null  object
#  3   member_casual       500684 non-null  object
#  4   start_station_name  500684 non-null  object
#  5   started_at          500684 non-null  datetime64[ns]
#  6   ended_at            500684 non-null  datetime64[ns]
#  7   start_station_id    500507 non-null  float64
#  8   end_station_id      500546 non-null  float64
#  9   end_station_name    500684 non-null  object
#  10  start_date          500684 non-null  datetime64[ns]
#  11  end_date            500684 non-null  datetime64[ns]
#  12  Duration            500684 non-null  object
#  13  Days                500684 non-null  int64
# ...

# %%
duration_is_0 = df[(df['started_at'])==df['ended_at']]
print (duration_is_0)

percent_duration_0 = (len(duration_is_0) / 532958) * 100
print (percent_duration_0)
# Out:
# 1.2627636699327152

# %%
 df['start_station_name'].unique()
# Out:
# array(['Michigan Ave & Lake St', 'W Oakdale Ave & N Broadway',
#        'Ashland Ave & Belle Plaine Ave', 'Fairbanks Ct & Grand Ave',
#        'Wells St & Evergreen Ave', 'Michigan Ave & 18th St',
#        'Mies van der Rohe Way & Chestnut St', 'Halsted St & Polk St',
#        'Albany Ave & Bloomingdale Ave', 'Lake Shore Dr & Diversey Pkwy',
#        'Elston Ave & Wabansia Ave', 'Clybourn Ave & Division St',
#        'Campbell Ave & Fullerton Ave', 'Clark St & Lake St',
#        'Sawyer Ave & Irving Park Rd', 'Financial Pl & Ida B Wells Dr',
#        'Wells St & Huron St', 'Shedd Aquarium',
#        'Bissell St & Armitage Ave', 'Franklin St & Lake St',
#        'Sedgwick St & Huron St', 'Dearborn Pkwy & Delaware Pl',
#        'Halsted St & Dickens Ave', 'Clark St & Schiller St',
#        'Michigan Ave & Washington St', 'Aberdeen St & Jackson Blvd',
#        'Wilton Ave & Diversey Pkwy', 'Wells St & Hubbard St',
#        'Archer (Damen) Ave & 37th St', 'Franklin St & Monroe St',
# ...

# %%
member_count = df[df['ended_at'] == df['started_at']]['member_casual'].value_counts()['member']
casual_count = df[df['ended_at'] == df['started_at']]['member_casual'].value_counts()['casual']

print(f"Member count with duration 0: {member_count}")
print(f"Casual count with duration 0: {casual_count}")
# Out:
# Member count with duration 0: 4457
# Casual count with duration 0: 2273

# %%
df = df.drop(df.loc[(df['started_at'])==df['ended_at']].index)

# %%
df.shape
# Out:
# (493954, 14)

# %%
'HUBBARD ST BIKE CHECKING (LBS-WH-TEST)'|'WATSON TESTING - DIVVY'
